# %% [markdown]
# # MLOps Experiment Tracking Notebook
#
# This notebook demonstrates the experiment phase before the production API pipeline.

# %%
from src.data import load_training_data, split_features_target
from src.train import train
df = load_training_data('data/raw/sample_churn.csv')
df.head()

# %%
metadata = train(data_path='data/raw/sample_churn.csv', model_type='random_forest')
metadata
